# %%
import sys
sys.path.append('..')
import numpy as np

# %%
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw
from IPython.display import SVG, Image

from utils.draw_utils import draw_molecule
IPythonConsole.molSize = (1000,1000)
# Out:
# RDKit WARNING: [14:48:14] Enabling RDKit 2019.09.3 jupyter extensions

# %%
source = Chem.MolFromSmarts('[Cl:1][C:2]1[CH:7]=[CH:6][C:5]([C:8]2[C:9]([C:16]3[CH:21]=[CH:20][CH:19]=[CH:18][CH:17]=3)=[CH:10][N:11]3[C:15]=2[CH2:14][CH2:13][CH2:12]3)=[CH:4][CH:3]=1')

# %%
source

# %%
source = Chem.MolFromSmiles('[Cl:1][C:2]1[CH:7]=[CH:6][C:5]([C:8]2[C:9]([C:16]3[CH:21]=[CH:20][CH:19]=[CH:18][CH:17]=3)=[CH:10][N:11]3[C:15]=2[CH2:14][CH2:13][CH2:12]3)=[CH:4][CH:3]=1')
product = Chem.MolFromSmiles('[Cl:1][C:2]1[CH:3]=[CH:4][C:5]([C:8]2[C:9]([C:16]3[CH:17]=[CH:18][CH:19]=[CH:20][CH:21]=3)=[C:10]([C:30]([O:41][C:37]([CH3:40])([CH3:39])[CH3:38])=[O:29])[N:11]3[C:15]=2[CH2:14][CH2:13][CH2:12]3)=[CH:6][CH:7]=1')

# %%
SVG(draw_molecule(source, node2color={}, dpa=100))

# %%
SVG(draw_molecule(product, node2color={}, dpa=100))

# %%
product

# %%
import pickle
from utils.draw_utils import draw_gt_reaction, get_react_prouct

# %%
test_dataset = pickle.load(open('../data/graphs/' + 'test.pkl', 'rb'))

# %%
idx = 23039
data = test_dataset[idx]
r_mol, p_mol = get_react_prouct(data['smarts'])

# %%
p, r  = draw_gt_reaction(data, mapping=True)

# %%
SVG(p)

# %%
SVG(r)

# %%
idx = 44841
data = test_dataset[idx]
r_mol, p_mol = get_react_prouct(data['smarts'])
p, r  = draw_gt_reaction(data, mapping=True)

# %%
SVG(r)

# %%
SVG(p)
