# %%
import sys
sys.path.append('../ChemicalReactivityPrediction/')

# %%
import dgl
import pandas as pd
import torch
import torch.nn as nn
import numpy as np
import pickle 

from dgl import DGLGraph
from utils.dataset import Dataset
from torch.nn.utils import clip_grad_norm_
from matplotlib import pyplot as plt
from sklearn.metrics import precision_recall_fscore_support

from reaction_predictors.graph_model.models import RGCNNClassifier
from utils.graph_utils import get_bonds, get_nodes, get_graph

# %%
def batch_gen(batch_size, n_test=20000, test=False, device='cuda', n_molecule_level=1, n_reaction_level=1):
    if not test:
        idxs = np.random.randint(0, len(dataset.dataset) - n_test, batch_size)
    else:
        idxs = np.random.randint(len(dataset.dataset) - n_test, len(dataset.dataset), batch_size)
    graphs = []
    targets = []
    for idx in idxs:
        g, target = get_graph(dataset, idx, bond2label, node2label, pad_length=pad_length, device=device, 
                              n_molecule_level=n_molecule_level, 
                             n_reaction_level=n_reaction_level)
        targets.append(target)
        graphs.append(g)
    graphs = dgl.batch(graphs)
    targets = torch.from_numpy(np.stack(targets)).to(device).float()
    return graphs, targets

# %%
def noam_decay(step,  model_size, warmup_steps=8000):
    return (
        model_size ** (-0.5) *
        min(step ** (-0.5), step * warmup_steps**(-1.5)))

# %%
def update_learning_rate(optimizer, step, model_size):
    lr = noam_decay(step, model_size)
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %%
def get_scores(tgts, predict):
    p, r, f, fm = [], [], [], []
    for t, pr in zip(tgts, predict):
        p_, r_, f_, _ =  precision_recall_fscore_support(t[t>-.1], pr[t>-.1], average='binary')
        p.append(p_)
        r.append(r_)
        f.append(f_)
    return p, r, f

# %%
dataset = pickle.load(open('../ChemicalReactivityPrediction/data/train_dataset_50.ipynb', 'rb'))

# %%
n_molecule_level=2
n_reaction_level=2
node2label = get_nodes(dataset, n_molecule_level=n_molecule_level, n_reaction_level=n_reaction_level)
bond2label = get_bonds(dataset, n_molecule_level=n_molecule_level, n_reaction_level=n_reaction_level, self_bond=True)

# %%
device='cuda:0'
max_num_atoms = 50
self_bond = True
pad_length = max_num_atoms + 15*n_molecule_level + n_molecule_level*n_reaction_level 
batch_size = 32
num_nodes = pad_length
num_rels = len(bond2label)
n_hidden = 128
lr = 1e-4
num_conv_layers=6
num_fcn_layers=2

# %%
model = RGCNNClassifier(len(node2label),
              num_nodes,
              batch_size,
              n_hidden,
              num_rels, 
              num_conv_layers, 
              num_fcn_layers
             )
model = model.to(device)
optimizer =  torch.optim.Adam(model.parameters(), lr=lr, betas=(0.9, 0.98), eps=1e-9)

# %%
optimizer =  torch.optim.Adam(model.parameters(), lr=lr, betas=(0.9, 0.98), eps=1e-9)

# %%
for p in model.parameters():
    if p.dim() > 1:
        nn.init.xavier_uniform_(p)

# %%
sigmoid = nn.Sigmoid()
bce_loss = nn.BCELoss()

# %%
train_pr_avg = []
train_re_avg = []
train_fs_avg = []
test_pr_avg = []
test_re_avg = []
test_fs_avg = []
train_fm_avg = []
test_fm_avg = []

# %%
step = 0
loss = 1
while loss > 0:
        model.train()
        step += 1
        batch, tgts = batch_gen(batch_size, device=device, n_molecule_level=n_molecule_level, n_reaction_level=n_reaction_level)
        optimizer.zero_grad()
        logits = model.forward(batch)
        loss = bce_loss(sigmoid(logits[:, :, 0])[tgts > -.1], tgts[tgts > -.1])
        loss.backward()
        clip_grad_norm_(model.parameters(), 0.01)
        optimizer.step()
        if step % 1000 == 1:
            with torch.no_grad():
                train_pr = []
                train_re = []
                train_fs = []
                test_pr = []
                test_re = []
                test_fs = []
                for _ in range(30):
                    optimizer.zero_grad()
                    batch, tgts = batch_gen(batch_size, device=device, n_molecule_level=n_molecule_level, n_reaction_level=n_reaction_level)               
                    predict = (model.forward(batch).cpu() > .5).int()[:, :, 0].numpy()
                    pr, re, fs = get_scores(tgts.cpu().numpy(), predict)
                    train_pr.extend(pr)
                    train_re.extend(re)
                    train_fs.extend(fs)

                    batch, tgts = batch_gen(batch_size, test=True, device=device, n_molecule_level=n_molecule_level, n_reaction_level=n_reaction_level)               
                    predict = (model.forward(batch).cpu() > .5).int()[:, :, 0].numpy()

                    pr, re, fs = get_scores(tgts.cpu().numpy(), predict)
                    test_pr.extend(pr)
                    test_re.extend(re)
                    test_fs.extend(fs)

                train_pr_avg.append(np.mean(train_pr))
                train_re_avg.append(np.mean(train_re))
                train_fs_avg.append(np.mean(train_fs))

                test_pr_avg.append(np.mean(test_pr))
                test_re_avg.append(np.mean(test_re))
                test_fs_avg.append(np.mean(test_fs))         
                train_fm_avg.append(np.mean(np.array(train_fs) > .99))
                test_fm_avg.append(np.mean(np.array(test_fs) > .99))

                plt.plot(train_fs_avg, label='Train F-measure')
                plt.plot(test_fs_avg, label='Test F-measure')
                plt.legend()
                plt.show()

                plt.plot(train_fm_avg, label='Train FMA')
                plt.plot(test_fm_avg, label='Test FMA')
                plt.legend()
                plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-98e8f22f48a9> in <module>
#       4         model.train()
#       5         step += 1
# ----> 6         batch, tgts = batch_gen(batch_size, device=device, n_molecule_level=n_molecule_level, n_reaction_level=n_reaction_level)
#       7         optimizer.zero_grad()
#       8         logits = model.forward(batch)
#
# <ipython-input-3-96a09ccf3720> in batch_gen(batch_size, n_test, test, device, n_molecule_level, n_reaction_level)
#       9         g, target = get_graph(dataset, idx, bond2label, node2label, pad_length=pad_length, device=device,
#      10                               n_molecule_level=n_molecule_level,
# ---> 11                              n_reaction_level=n_reaction_level)
#      12         targets.append(target)
#      13         graphs.append(g)
#
# ~/Science/ChemicalReactivityPrediction/utils/graph_utils.py in get_graph(dataset, idx, bond2label, node2label, n_molecule_level, n_reaction_level, self_bond, pad_length, device)
#     122     g.add_nodes(len(nodes))
#     123     g.ndata['id'] = torch.from_numpy(np.array(nodes)).to(device)
# --> 124     g.add_edges(np.array(sender), np.array(reciever))
#     125     g.edata['norm'] = torch.from_numpy(np.array(norm).reshape(-1, 1)).to(device).float()
#     126     g.edata['rel_type'] = torch.from_numpy(np.array(bonds)).to(device)
#
# ~/miniconda3/envs/chem/lib/python3.6/site-packages/dgl/graph.py in add_edges(self, u, v, data)
#    1112         if self._msg_index is not None:
#    1113             self._msg_index = self._msg_index.append_zeros(num)
# -> 1114         self._msg_frame.add_rows(num)
#    1115
#    1116     def remove_nodes(self, vids):
#
# ~/miniconda3/envs/chem/lib/python3.6/site-packages/dgl/frame.py in add_rows(self, num_rows)
#     752         if not self.is_span_whole_column():
#     753             raise RuntimeError('FrameRef not spanning whole column.')
# --> 754         self._frame.add_rows(num_rows)
#     755         if self._index.slice_data() is not None:
#     756             # the index is a slice
#
# ~/miniconda3/envs/chem/lib/python3.6/site-packages/dgl/frame.py in add_rows(self, num_rows)
#     381         """
#     382         feat_placeholders = {}
# --> 383         for key, col in self._columns.items():
#     384             scheme = col.scheme
#     385             ctx = F.context(col.data)
#
# KeyboardInterrupt:

# %%
 plt.plot(train_fs_avg, label='Train F-measure')
plt.plot(test_fs_avg, label='Test F-measure')
plt.legend()
plt.show()

plt.plot(train_fm_avg, label='Train FMA')
plt.plot(test_fm_avg, label='Test FMA')
plt.legend()
plt.show()
