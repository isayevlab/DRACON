# %%
import sys
sys.path.append('../ChemicalReactivityPrediction/')

# %%
import dgl
import pandas as pd
import torch
import torch.nn as nn
import numpy as np
import pickle 

from dgl import DGLGraph
from utils.dataset import Dataset
from torch.nn.utils import clip_grad_norm_
from matplotlib import pyplot as plt
from sklearn.metrics import precision_recall_fscore_support

from reaction_predictors.graph_model.models import RGCNNClassifier
from utils.graph_utils import get_bonds, get_nodes, get_graph

# %%
def batch_gen(batch_size, n_test=20000, test=False, device='cuda', n_molecule_level=1, n_reaction_level=1):
    if not test:
        idxs = np.random.randint(0, len(dataset.dataset) - n_test, batch_size)
    else:
        idxs = np.random.randint(len(dataset.dataset) - n_test, len(dataset.dataset), batch_size)
    graphs = []
    targets = []
    for idx in idxs:
        g, target = get_graph(dataset, idx, bond2label, node2label, 
                              pad_length=pad_length, device=device, 
                              n_molecule_level=n_molecule_level, 
                             n_reaction_level=n_reaction_level)
        targets.append(target)
        graphs.append(g)
    graphs = dgl.batch(graphs)
    targets = torch.from_numpy(np.stack(targets)).to(device).float()
    return graphs, targets

# %%
def noam_decay(step,  model_size, warmup_steps=8000):
    return (
        model_size ** (-0.5) *
        min(step ** (-0.5), step * warmup_steps**(-1.5)))

# %%
def update_learning_rate(optimizer, step, model_size):
    lr = noam_decay(step, model_size)
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %%
def get_scores(tgts, predict):
    p, r, f, fm = [], [], [], []
    for t, pr in zip(tgts, predict):
        p_, r_, f_, _ =  precision_recall_fscore_support(t[t>-.1], pr[t>-.1], average='binary')
        p.append(p_)
        r.append(r_)
        f.append(f_)
    return p, r, f

# %%
dataset = pickle.load(open('../ChemicalReactivityPrediction/data/train_dataset_50.ipynb', 'rb'))

# %%
n_molecule_level=1
n_reaction_level=0
node2label = get_nodes(dataset, n_molecule_level=n_molecule_level, n_reaction_level=n_reaction_level)
bond2label = get_bonds(dataset, n_molecule_level=n_molecule_level, n_reaction_level=n_reaction_level, self_bond=True)

# %%
device='cuda:0'
max_num_atoms = 50
self_bond = True
pad_length = max_num_atoms + 15*n_molecule_level + n_molecule_level*n_reaction_level 
batch_size = 32
num_nodes = pad_length
num_rels = len(bond2label)
n_hidden = 64
lr = 1e-3
num_conv_layers=4
num_fcn_layers=2

# %%
model = RGCNNClassifier(len(node2label),
              num_nodes,
              batch_size,
              n_hidden,
              num_rels, 
              num_conv_layers, 
              num_fcn_layers
             )
model = model.to(device)
optimizer =  torch.optim.Adam(model.parameters(), lr=lr, betas=(0.9, 0.98), eps=1e-9)

# %%
for p in model.parameters():
    if p.dim() > 1:
        nn.init.xavier_uniform_(p)

# %%
sigmoid = nn.Sigmoid()
bce_loss = nn.BCELoss()

# %%
train_pr_avg = []
train_re_avg = []
train_fs_avg = []
test_pr_avg = []
test_re_avg = []
test_fs_avg = []
train_fm_avg = []
test_fm_avg = []

# %%
step = 0
loss = 1
while loss > 0:
        model.train()
        step += 1
        batch, tgts = batch_gen(batch_size, device=device, n_reaction_level=n_reaction_level)
        optimizer.zero_grad()
        logits = model.forward(batch)
        loss = bce_loss(sigmoid(logits[:, :, 0])[tgts > -.1], tgts[tgts > -.1])
        loss.backward()
        clip_grad_norm_(model.parameters(), 0.01)
        optimizer.step()
        if step % 1000 == 1:
            with torch.no_grad():
                train_pr = []
                train_re = []
                train_fs = []
                test_pr = []
                test_re = []
                test_fs = []
                for _ in range(30):
                    optimizer.zero_grad()
                    batch, tgts = batch_gen(batch_size, device=device, n_reaction_level=n_reaction_level)               
                    predict = (model.forward(batch).cpu() > .5).int()[:, :, 0].numpy()
                    pr, re, fs = get_scores(tgts.cpu().numpy(), predict)
                    train_pr.extend(pr)
                    train_re.extend(re)
                    train_fs.extend(fs)

                    batch, tgts = batch_gen(batch_size, test=True, device=device, n_reaction_level=n_reaction_level)            
                    predict = (model.forward(batch).cpu() > .5).int()[:, :, 0].numpy()

                    pr, re, fs = get_scores(tgts.cpu().numpy(), predict)
                    test_pr.extend(pr)
                    test_re.extend(re)
                    test_fs.extend(fs)

                train_pr_avg.append(np.mean(train_pr))
                train_re_avg.append(np.mean(train_re))
                train_fs_avg.append(np.mean(train_fs))

                test_pr_avg.append(np.mean(test_pr))
                test_re_avg.append(np.mean(test_re))
                test_fs_avg.append(np.mean(test_fs))         
                train_fm_avg.append(np.mean(np.array(train_fs) > .99))
                test_fm_avg.append(np.mean(np.array(test_fs) > .99))

                plt.plot(train_fs_avg, label='Train F-measure')
                plt.plot(test_fs_avg, label='Test F-measure')
                plt.legend()
                plt.show()

                plt.plot(train_fm_avg, label='Train FMA')
                plt.plot(test_fm_avg, label='Test FMA')
                plt.legend()
                plt.show()
# Out:
# /home/socrates/miniconda3/envs/chem/lib/python3.6/site-packages/dgl/base.py:18: UserWarning: Initializer is not set. Use zero initializer instead. To suppress this warning, use `set_initializer` to explicitly specify which initializer to use.
#   warnings.warn(msg)
# /home/socrates/miniconda3/envs/chem/lib/python3.6/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-819ecb077e35> in <module>
#       9         loss = bce_loss(sigmoid(logits[:, :, 0])[tgts > -.1], tgts[tgts > -.1])
#      10         loss.backward()
# ---> 11         clip_grad_norm_(model.parameters(), 0.01)
#      12         optimizer.step()
#      13         if step % 1000 == 1:
#
# ~/miniconda3/envs/chem/lib/python3.6/site-packages/torch/nn/utils/clip_grad.py in clip_grad_norm_(parameters, max_norm, norm_type)
#      22     if isinstance(parameters, torch.Tensor):
#      23         parameters = [parameters]
# ---> 24     parameters = list(filter(lambda p: p.grad is not None, parameters))
#      25     max_norm = float(max_norm)
#      26     norm_type = float(norm_type)
#
# ~/miniconda3/envs/chem/lib/python3.6/site-packages/torch/nn/modules/module.py in parameters(self, recurse)
#     880
#     881         """
# --> 882         for name, param in self.named_parameters(recurse=recurse):
#     883             yield param
#     884
#
# ~/miniconda3/envs/chem/lib/python3.6/site-packages/torch/nn/modules/module.py in named_parameters(self, prefix, recurse)
#     906             lambda module: module._parameters.items(),
#     907             prefix=prefix, recurse=recurse)
# --> 908         for elem in gen:
#     909             yield elem
#     910
#
# ~/miniconda3/envs/chem/lib/python3.6/site-packages/torch/nn/modules/module.py in _named_members(self, get_members_fn, prefix, recurse)
#     850         memo = set()
#     851         modules = self.named_modules(prefix=prefix) if recurse else [(prefix, self)]
# --> 852         for module_prefix, module in modules:
#     853             members = get_members_fn(module)
#     854             for k, v in members:
#
# ~/miniconda3/envs/chem/lib/python3.6/site-packages/torch/nn/modules/module.py in named_modules(self, memo, prefix)
#    1048                     continue
#    1049                 submodule_prefix = prefix + ('.' if prefix else '') + name
# -> 1050                 for m in module.named_modules(memo, submodule_prefix):
#    1051                     yield m
#    1052
#
# ~/miniconda3/envs/chem/lib/python3.6/site-packages/torch/nn/modules/module.py in named_modules(self, memo, prefix)
#    1048                     continue
#    1049                 submodule_prefix = prefix + ('.' if prefix else '') + name
# -> 1050                 for m in module.named_modules(memo, submodule_prefix):
#    1051                     yield m
#    1052
#
# ~/miniconda3/envs/chem/lib/python3.6/site-packages/torch/nn/modules/module.py in named_modules(self, memo, prefix)
#    1048                     continue
#    1049                 submodule_prefix = prefix + ('.' if prefix else '') + name
# -> 1050                 for m in module.named_modules(memo, submodule_prefix):
#    1051                     yield m
#    1052
#
# KeyboardInterrupt:

# %%
plt.plot(test_fm_avg, label='Test FMA')
